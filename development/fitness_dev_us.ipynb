# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tck
import numpy as np
from cycler import cycler
from matplotlib import colors as mcolors
import datetime
import seaborn as sns

from pathlib import Path
import sys

# Add the parent directory to the Python path
sys.path.append(str(Path.cwd().parent))

from fitness_viz_funcs import *
from old_fitness_viz_funcs import *

# %% [markdown]
# # Old Way

# %%
us_data = {
    'Jarryd'    : {'goal': 40, 'weekly_progress': [5, 5, 5, 5]},

    'Alex'      : {'goal': 40, 'weekly_progress': [5, 5, 7, 3]},

    'Travis'    : {'goal': 32, 'weekly_progress': [2, 2, 3, 3]},

    'Ondray'    : {'goal': 40, 'weekly_progress': [2, 3, 5, 3]},

    'Brandon'   : {'goal': 28, 'weekly_progress': [2, 4, 4, 3]}
}

weekly_plot_old(us_data, 8, title="January 6th - March 2nd", save=True)
# Out:
# (<Figure size 1200x1000 with 2 Axes>,
#  array([<Axes: title={'center': 'Current Progress vs Goal'}, ylabel='Percent Completed (%)'>,
#         <Axes: title={'center': 'Weekly Progress and Projections'}, xlabel='Week', ylabel='Cumulative Exercises'>],
#        dtype=object))

# %%
excel_data = pd.read_excel('./data_us.xlsx', sheet_name='Data')

# %%
excel_data
# Out:
#     Challenge  Week Participant  Week Start  Cardio  Resistance Training  \
# 0         NaN   NaN      Jarryd  2024.09.02     1.0                  3.0
# 1         NaN   NaN          Al  2024.09.02     1.0                  3.0
# 2         NaN   NaN        Trav  2024.09.02     4.0                  1.0
# 3         1.0   1.0      Jarryd  2024.09.09     5.0                  1.0
# 4         NaN   NaN          Al  2024.09.09     2.0                  3.0
# ..        ...   ...         ...         ...     ...                  ...
# 73        NaN   NaN          Al  2025.02.17     NaN                  NaN
# 74        NaN   NaN        Trav  2025.02.17     NaN                  NaN
# 75        NaN  13.0      Jarryd  2025.02.24     NaN                  NaN
# 76        NaN   NaN          Al  2025.02.24     NaN                  NaN
# 77        NaN   NaN        Trav  2025.02.24     NaN                  NaN
#
#       Steps  Weight  Weight Change (lbs)  Distance (miles)  Alcohol
# ...

# %%
excel_data[excel_data['Participant'] == 'Jarryd']['Weight']
# Out:
# 0       NaN
# 3       NaN
# 6       NaN
# 9       NaN
# 12      NaN
# 15      NaN
# 18      NaN
# 21      NaN
# 24    163.4
# 27    163.2
# 30    162.4
# 33    160.8
# 36    161.2
# 39    161.2
# 42    164.4
# 45      NaN
# 48      NaN
# 51      NaN
# 54      NaN
# 57      NaN
# 60      NaN
# 63      NaN
# 66      NaN
# 69      NaN
# 72      NaN
# 75      NaN
# Name: Weight, dtype: float64

# %%
excel_data[excel_data['Participant'] == 'Jarryd']['Weight']
