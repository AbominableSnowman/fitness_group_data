# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tck
import numpy as np
from cycler import cycler
from matplotlib import colors as mcolors
import datetime
import seaborn as sns

from pathlib import Path
import sys

# Add the parent directory to the Python path
sys.path.append(str(Path.cwd().parent))

from fitness_viz_funcs import *

# %%
data_old = {
    'Jarryd'    : {'goal': 20, 'weekly_progress': [2, 2, 4, 4, 1]},

    'David'     : {'goal': 10, 'weekly_progress': [1, 0, 3, 1, 3]},

    'Malay'     : {'goal': 15, 'weekly_progress': [2, 2, 3, 2, 2]},

    'Yousef'    : {'goal': 20, 'weekly_progress': [4, 4, 4, 4, 1]},

    'Paula'     : {'goal': 18, 'weekly_progress': [4, 5, 4, 5, 4]},

    'Justin'    : {'goal': 10, 'weekly_progress': [2, 0, 0, 1, 4]},

    'Elisabeth' : {'goal': 10, 'weekly_progress': [1, 1, 0, 3, 3]},

    'Vanessa'   : {'goal': 15, 'weekly_progress': [3, 3, 3, 3, 3]}
}

# %% [markdown]
# # Eff it, starting from scratch

# %%
data, goals = extract_eu_data(data_range="Data!A1:L86", goals_range="Goals!A1:K13")
# Out:
# Credentials loaded from token.json
# Credentials refreshed.

# %%
fig, ax = weekly_plot(12, data, goals, "Challenge #12: January 6th - March 2nd")

# %% [markdown]
# # Giving up - EU

# %%
eu_data = {
    'Jarryd'    : {'goal': 40, 'weekly_progress': [5]},

    'David'     : {'goal': 40, 'weekly_progress': [4]},

    'Malay'     : {'goal': 32, 'weekly_progress': [2]},

    'Shanya'    : {'goal': 24, 'weekly_progress': [1]},

    'Yousef'    : {'goal': 32, 'weekly_progress': [2]},

    'Paula'     : {'goal': 32, 'weekly_progress': [5]},

    'Justin'    : {'goal': 24, 'weekly_progress': [2]},

    'Elisabeth' : {'goal': 32, 'weekly_progress': [3]},

    'Vanessa'   : {'goal': 24, 'weekly_progress': [4]}
}

weekly_plot_old(eu_data, 8, title="January 6th - March 2nd")
# Out:
# (<Figure size 1200x1000 with 2 Axes>,
#  array([<Axes: title={'center': 'Current Progress vs Goal'}, ylabel='Percent Completed (%)'>,
#         <Axes: title={'center': 'Weekly Progress and Projections'}, xlabel='Week', ylabel='Cumulative Exercises'>],
#        dtype=object))

# %%
# Out:
# (<Figure size 1200x1000 with 2 Axes>,
#  array([<Axes: title={'center': 'Current Progress vs Goal'}, ylabel='Percent Completed (%)'>,
#         <Axes: title={'center': 'Weekly Progress and Projections'}, xlabel='Week', ylabel='Cumulative Exercises'>],
#        dtype=object))

# %%
import datetime

# %%
q1 = datetime.date(2025, 3, 31) - datetime.date(2025, 1, 1)

# %%
dir(q1)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  'days',
#  'max',
#  'microseconds',
#  'min',
#  'resolution',
#  'seconds',
#  'total_seconds']
